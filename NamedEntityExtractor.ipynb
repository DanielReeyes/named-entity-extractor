# %%
import spacy
import pandas as pd
import itertools
import os
import numpy as np
nlp = spacy.load('pt')

# %%
pwd = %pwd
pwd = os.path.join(os.path.dirname(pwd), 'data')
data = pd.read_csv(os.path.join(pwd, 'input/new_data_part_23.csv'), sep=';').replace({np.NaN: None})

#data = data.head(10)

# %%
list_sentence = data.Sentença.tolist()
d = []

for sentence in list_sentence:
    count = 0
    doc = nlp(sentence)
    entities = doc.ents
    vector_entities = [entidade.text for entidade in entities if len(entidade.text) > 1]
    vector_type_entities = [entidade.label_ for entidade in entities if len(entidade.label_) > 1]
    dictEntities = {vector_entities[i]: vector_type_entities[i] for i in range(len(vector_entities))}
    #print ("Resultant dictionary is : " +  str(dictEntities))
    
    if (len(set(vector_entities))) > 1:
        for comb in itertools.combinations(set(vector_entities), 2):
            ent1 = comb[0]
            ent2 = comb[1]

            d.append(
                {
                    'Sentença': sentence,
                    'Entidade 1': ent1,
                    'Tipo Entidade 1': dictEntities[ent1],
                    'Relacao': "",
                    'Entidade 2 ': ent2,
                    'Tipo Entidade 2 ': dictEntities[ent2]
                }
            )
    else:
        print('Sentença \' ' + sentence + ' \' possui '+ str(len(set(vector_entities))) +' entidade identificada. Verifique.')
        print(set(vector_entities))
# Out:
# Sentença ' A decisão foi tomada depois que a pandemia de covid-19 acelerou a evolução digital, reduziu o fluxo das agências e jogou holofotes para a necessidade de modernização de plataformas e sistemas em meio a um mercado em iminente transformação. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Ana Botín, presidente-executivo do conselho, disse que a pandemia acelerou a transformação digital e que o banco também precisa seguir nesse caminho, para atrair novos clientes e gerar valor. ' possui 1 entidade identificada. Verifique.
# {'Ana Botín'}
# Sentença ' O acordo vai desenvolver estratégias de melhoria das condições de acesso dos pequenos negócios aos serviços financeiros do banco. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O anúncio foi feito durante as comemorações do Dia da Mulher, nesta segunda-feira 2. ' possui 1 entidade identificada. Verifique.
# {'Dia da Mulher'}
# Sentença ' O projeto foi aprovado por unanimidade e volta para nova votação na Câmara, que deve acontecer até o fim do mês. ' possui 1 entidade identificada. Verifique.
# {'Câmara'}
# Sentença ' De acordo com a instituição, foram originadas mais de R$ 43 milhões em propostas durante os dias do evento, que surgiu para preencher um espaço deixado pelas feiras presenciais, suspensas ou canceladas em todo o País por conta do coronavírus. ' possui 1 entidade identificada. Verifique.
# {'País'}
# Sentença ' O Tips é um serviço que liquida pagamentos em dinheiro do banco central em tempo real e 24 horas por dia. ' possui 1 entidade identificada. Verifique.
# {'Tips'}
# Sentença ' Atualmente, ele suporta a liquidação de pagamentos instantâneos em euros, mas também tem a capacidade funcional de suportar outras moedas. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O projeto com o banco central da Suécia começará este mês com a primeira liquidação de pagamentos instantâneos entre euros e coroas suecas prevista para maio de 2022. ' possui 1 entidade identificada. Verifique.
# {'Suécia'}
# Sentença ' A iniciativa surge como uma resposta às crescentes necessidades dos consumidores e das empresas que resultam do crescimento de e -comércio, turismo e fluxos migratórios. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O WhatsApp planeja se unir a mais bancos indianos para expandir serviços bancários em áreas rurais e para indivíduos de baixa renda. ' possui 1 entidade identificada. Verifique.
# {'WhatsApp planeja'}
# Sentença ' A máquina trafega por entre os campos e analisa cada planta individualmente na expectativa de coletar dados para os fazendeiros, como áreas que carecem de fertilizante e outras que poderiam se beneficiar com uma borrifada de algum nutriente. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Ele agora será, além de serviço de maquininhas, um ecossistema de meios de pagamento, que deve incluir seguros, cartões de crédito e loja virtual. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O primeiro novo produto é o Crédito Fácil SafraPay, linha voltada para o pequeno e médio empreendedor, baseada no faturamento mensal e com taxas a partir de 1,69%. ' possui 1 entidade identificada. Verifique.
# {'Crédito Fácil SafraPay'}
# Sentença ' O acúmulo de pontos segue a proporção de 1 para R$1 na troca por revisões, peças, acessórios ou desconto em um novo Mitsubishi. ' possui 1 entidade identificada. Verifique.
# {'Mitsubishi'}
# Sentença ' Caso a opção for trocá-los por revisões, o cliente tem a possibilidade de realizar até 6 delas sem fazer desembolso. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O ano de 2020 está provando que as empresas precisam criar um diálogo e pensar primeiro nos clientes. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Vinte e cinco por cento dos consumidores que participaram da pesquisa afirmam que se afastaram de marcas que, de acordo com sua percepção, estavam agindo apenas por interesse próprio. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O aplicativo da Ame está disponibilizando empréstimos de até R$ 50 mil, com mais ofertas de linhas de crédito pessoal. ' possui 1 entidade identificada. Verifique.
# {'Ame'}
# Sentença ' A carteira digital, em parceria com a plataforma Lendico, possui taxas de juros superiores a 3,34% ao mês, com parcelamentos em até 36 meses 3 anos ' possui 1 entidade identificada. Verifique.
# {'Lendico'}
# Sentença ' A inauguração será realizada por meio de uma transmissão ao vivo, pelo YouTube, em que serão apresentadas as instalações da nova unidade. ' possui 1 entidade identificada. Verifique.
# {'YouTube'}
# Sentença ' A live terá início às 8h30, com participação dos dirigentes da cooperativa e da equipe que vai atuar no local. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Segundo o gerente da unidade, Tiago Moschen, a proposta é fazer uma inauguração direcionada para as novas tecnologias de transmissão online, mantendo a tradição com segurança e tranquilidade que o momento exige. ' possui 1 entidade identificada. Verifique.
# {'Tiago Moschen'}
# Sentença ' A maioria das perguntas será respondida por um chatbot, mas onde os clientes exigirem respostas mais complexas, haverá um agente de atendimento ao cliente disponível para responder. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Com capital inicial de R$ 100 milhões, trata-se da primeira instituição financeira com capital 100% estrangeiro a obter autorização de funcionamento e operação junto ao Banco Central BC. ' possui 1 entidade identificada. Verifique.
# {'Banco Central BC'}
# Sentença ' A expectativa do banco é movimentar entre R$ 400 milhões e R$ 500 milhões em operações de crédito no primeiro ano, com meta é atingir equilíbrio break even point em três anos. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Segundo o banco, em um primeiro momento o banco irá ofertar produtos financeiros diversos, como financiamento de máquinas, leasing e investimentos, aos clientes do grupo, revendedores e a indústria de modo geral. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O banco será o cotista único de um fundo de corporate venture, cujo objetivo é comprar fatias minoritárias de fintechs. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Queremos ser o banco que vai conseguir acelerar e apoiar a maior gama possível de startups ao longo de todo o seu ciclo de vida. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Neste ano, banco já forneceu mais de R$ 2 bilhões de crédito para startups e companhias de tecnologia. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Além disso, a equipe comercial do banco de atacado já faz uma cobertura de mais de 1,1 mil empresas iniciantes. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O banco do Reino Unido está convidando clientes para participar do teste, que usará tecnologia da empresa de fintech CoGo. ' possui 1 entidade identificada. Verifique.
# {'Reino Unido'}
# Sentença ' Ao todo foram desembolsados R$ 3,7 bilhões – R$ 700 milhões a mais do que os previstos inicialmente. ' possui 1 entidade identificada. Verifique.
# {'– R$'}
# Sentença ' Em três dias acessarem o crédito 37 mil micros e pequenas empresas clientes do banco, que contrataram via aplicativo. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Até sexta-feira, o Itaú já havia concedido 70% dos R$ 3 bilhões disponíveis para a linha. ' possui 1 entidade identificada. Verifique.
# {'Itaú'}
# Sentença ' O distanciamento social e o pagamento do auxílio emergencial por contas digitais aceleraram o processo de bancarização no Brasil. ' possui 1 entidade identificada. Verifique.
# {'Brasil'}
# Sentença ' De acordo com dados do BC, 9,8 milhões de pessoas iniciaram relacionamento com instituição financeira de março para cá. ' possui 1 entidade identificada. Verifique.
# {'BC'}
# Sentença ' O documento chama a atenção para o fato de os títulos verdes emitidos em moeda local serem ofertados majoritariamente por empresas não financeiras, sendo que 76% delas atuam no setor de energias renováveis. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O restante é de empresas dos ramos de papel, celulose e alimentos. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Instalado no campus de pesquisa Riseholme Agri-tech da Universidade de Lincoln, o laboratório promete ajudar as comunidades agrícolas rurais a se tornarem líderes na aplicação de tecnologia à agricultura. ' possui 1 entidade identificada. Verifique.
# {'Riseholme Agri-tech da Universidade de Lincoln'}
# Sentença ' Ele abrigará um laboratório de robótica dedicado, uma embalagem de demonstração e um corredor modelo de supermercado refrigerado disponível para empresários e pesquisadores. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O estoque total de crédito no Brasil subiu 0,8% em junho sobre maio, a 3,625 trilhões de reais, resultado guiado principalmente pelo aumento de financiamentos a empresas em meio à operação de programas mais recentemente voltados para pequenos negócios. ' possui 1 entidade identificada. Verifique.
# {'Brasil'}
# Sentença ' Com isso, o estoque total passou a 50,4% do Produto Interno Bruto PIB. ' possui 1 entidade identificada. Verifique.
# {'Produto Interno Bruto PIB'}
# Sentença ' Enquanto entre empresas o crescimento do crédito foi de 1% em junho ante maio, entre famílias a elevação foi de 0,7%. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O estudo ouviu mais de 12 mil pessoas, de 12 países, incluindo o Brasil, no 1º semestre deste ano. ' possui 1 entidade identificada. Verifique.
# {'Brasil'}
# Sentença ' A primeira onda do estudo mostra que, na hora da compra, os consumidores brasileiros priorizam a relação custo-benefício 82%, a facilidade 73%, a segurança 71% e a confiança na marca 68%. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença 
' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O indicador mostra ainda que a procura por dinheiro emprestado foi maior entre os brasileiros que ganham até R$ 500. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Neste caso, o aumento, em julho comparado a junho, foi de 18,7%. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' E a área de serviços financeiros é uma das prioridades da Vivo para o desenvolvimento de novos serviços que gerem valor para seus assinantes. ' possui 1 entidade identificada. Verifique.
# {'Vivo'}
# Sentença ' para acelerar o crescimento da plataforma. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Para as empresas, a opção é válida para os financiamentos à produção de empreendimentos e para os financiamentos de aquisição e construção de imóveis comerciais. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' As opções de pagamento parcial dos encargos ou carência também serão estendidas para até 180 dias, porém não poderão ser utilizadas em conjunto com a pausa. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Durante o período de pausa, o contrato não está isento da incidência de juros remuneratórios, seguros e taxas. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Os valores dos encargos pausados são acrescidos ao saldo devedor do contrato e diluídos no prazo remanescente. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' A taxa de juros e o prazo contratados inicialmente não sofrem alteração. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' A opção é dada a cerca de 3 milhões de usuários das contas digitais criadas pela empresa para as redes parceiras. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Para elas, a vantagem é dar vazão aos pagamentos recebidos em dinheiro, reduzindo o risco de assaltos e a demanda com aluguel de carros fortes para o transporte dessas quantias. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Pelo acordo, a Natura tem direito de adquirir 100% da startup futuramente. ' possui 1 entidade identificada. Verifique.
# {'Natura'}
# Sentença ' A Natura pretende oferecer uma nova plataforma de serviços para as consultoras de beleza da marca, como maquiagem, cabeleireiro, manicure, entre outros. ' possui 1 entidade identificada. Verifique.
# {'Natura'}
# Sentença ' As profissionais que são contratadas através da plataforma usariam os produtos do grupo como forma de promover a marca. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Com o investimento é esperado que a Singu expanda sua base de clientes, que hoje é de cerca de 200 mil cadastrados na plataforma, e o número de profissionais de beleza parceiros, cifra que ultrapassa os 3 mil. ' possui 1 entidade identificada. Verifique.
# {'Singu'}
# Sentença ' A grande novidade é que, até o fim do mês de julho, qualquer pessoa de fora da rede também poderá ser um novo empreendedor, integrando-se a plataforma. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O sucesso tem sido tão significativo que criamos uma unidade de negócio para gerir a plataforma e expandir a iniciativa, gerando fluxo de novos consumidores no ambiente omnichannel. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Os 10 participantes com melhor performance no mês recebem a comissão em dobro. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' A estratégia está em linha com o objetivo de inovar nos formatos, explorar ações de compartilhamento de receita e estimular ainda mais o comportamento empreendedor nos times. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Temos anos e anos de experiência pegando dados brutos, convertendo em modelos de análise e entendendo o risco de crédito afirma Gleason. ' possui 1 entidade identificada. Verifique.
# {'Gleason'}
# Sentença ' Vai demorar muito para essas empresas estarem nesse patamar. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Temos um plano agressivo e queremos ter uma fatia entre 20% e 25% do mercado de carteiras digitais no prazo de três anos. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Ter um espaço para diálogo interno dos funcionários, pesquisa e metas compartilhadas são passos imprescindíveis para estimular a compreensão sobre a diversidade e inclusão, evoluindo cada vez mais para a adoção de práticas inclusivas, construção de novos negócios e para a atração e retenção de profissionais na empresa. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Ter uma conta digital tem se tornado algo cada vez mais comum. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Não é à toa, portanto, que cada vez mais também apareçam bancos digitais de nicho, que procuram agradar alguns segmentos mais específicos da população. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' O objetivo dos bancos digitais de nicho é oferecer um pouco mais de personalização aos clientes, como um atendimento diferenciado e até produtos, serviços e promoções que tenham a ver com determinados grupos. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Deste modo, o objetivo é tentar colocar em prática soluções mais específicas para dores ou demandas comuns. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Textos, fotos, artes e vídeos do Valor estão protegidos pela legislação brasileira sobre direito autoral. ' possui 1 entidade identificada. Verifique.
# {'Valor'}
# Sentença ' Todas essas transformações estão em linha com uma tendência mundial de digitalização das moedas. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' Uma das ferramentas a ser disponibilizadas para esse público é uma plataforma, recentemente atualizada, agora com versão web e app que já conta com a adesão de ligas acadêmicas, atléticas, centros acadêmicos e escolas de medicina parceiras. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' A novidade foi anunciada na quarta-feira, 12 de agosto. ' possui 0 entidade identificada. Verifique.
# set()
# Sentença ' A ideia dele na Global Forest Bond é integrar, por meio de produtos financeiros, a economia global e a preservação dos ecossistemas. ' possui 1 entidade identificada. Verifique.
# {'Global'}
# Sentença ' As novas unidades paranaenses carregam as características do projeto conceito desenvolvido pela cooperativa que agrega tecnologia, arquitetura de ponta e multifuncionalidade, transformando os espaços em umas das agências mais modernas do Brasil. ' possui 1 entidade identificada. Verifique.
# {'Brasil'}
# Sentença ' Para as pessoas físicas, o benefício será de ter o dinheiro na mão na hora mais necessária, enquanto os empregadores deixarão de precisar dispor de seu caixa para ajudar o empregado – a operação será toda custeada pela Creditas. ' possui 1 entidade identificada. Verifique.
# {'Creditas'}
# Sentença ' A antecipação poderá ser feita com base nos dias que o funcionário já trabalhou naquele mês, sem ter de esperar até o quinto dia útil do mês seguinte para receber. ' possui 0 entidade identificada. Verifique.
# set()

# %%
df = pd.DataFrame(d)
df.head(5)
# Out:
#                                             Sentença        Entidade 1  \
# 0  O Santander Brasil vai investir R$ 90 milhões ...  Santander Brasil
# 1  O Santander Brasil vai investir R$ 90 milhões ...  Santander Brasil
# 2  O Santander Brasil vai investir R$ 90 milhões ...    América Latina
# 3  À frente do projeto está Marcelo Labuto, ex-pr...   Banco do Brasil
# 4  À frente do projeto está Marcelo Labuto, ex-pr...   Banco do Brasil
#
#   Tipo Entidade 1 Relacao     Entidade 2  Tipo Entidade 2
# 0             ORG          América Latina              LOC
# 1             ORG                  Zurich              PER
# 2             LOC                  Zurich              PER
# 3             ORG           BB Seguridade              ORG
# 4             ORG               Santander              ORG

# %%
df.shape
# Out:
# (462, 6)

# %%
pwd = %pwd
pwd = os.path.join(os.path.dirname(pwd), 'data')
full_path = os.path.join(pwd, 'input\sentence_annoted_part_23.csv')
print(full_path)
# Out:
# D:\Mestrado\2020-02\Deep Learning\relation-extraction-deep-learning\data\input\sentence_annoted_part_23.csv

# %%
df.to_csv(full_path, sep=';', encoding="utf-8-sig", index=False)
